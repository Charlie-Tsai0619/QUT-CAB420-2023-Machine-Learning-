# %% [markdown]
# # CAB420 Assignment 1B Question 2: Template
#
# ## Overview
#
# This notebook provides a helper function to load in the Oxford-IIIT Pets dataset suitable for classification and semantic segmentation.
#
# It also provides an example of how to load in the MobileNetV3Small Network which you are required to fine tune for the second part of the question.
#
# Please read the comments and instructions within this notebook. It has been carefully designed to help you with many of the tasks required.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import matplotlib.pyplot as plt
from matplotlib import gridspec


import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, concatenate, BatchNormalization, SpatialDropout2D, Activation, Flatten
from tensorflow.keras.models import Model


import numpy as np
import pandas as pd
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing import image_dataset_from_directory
import keras
import glob
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score

# %% [markdown]
# ## Loading in the data
#
# We first provide some helper functions to format the data in the way we need. You shouldn't need to change these, though you are welcome to if you like.

# %%
def preprocess_segmentation_mask(segmentation_mask):
    """preprocess the semgentation mask

    The original segmentation mask has three categories.
      foreground, background and outline
    This function will just convert it to foreground and background 

    The original segmentation mask is also 1-index, so will convert it
    to 0-index.

    the original mask is represented as:
    1 - edge of dog/cat and things like leashes etc.
    2 - background
    3 - foreground

    we want to just keep the merge the edges and foreground of the doggo/catto, and
    then treat it as a binary semantic segmentation task.
    To achieve this, we will just subtract two, converting to values of [-1, 0, 1],
    and then apply the abs function to convert the -1 values (edges) to the foreground.

    Will also convert it to 32 bit float which will be needed for working with tf.
    
    Why am I doing it this way?
     A reasonable question. Initially I tried to do it with just normal array indexing,
     but this is a bit more work since the mask is a tensorflow tensor and not a np array.
     We could alternatively convert it to an array, perform indexing and then map it back,
     but this would have a performance overhead, which wouldn't be a big deal, but still.
     With all that being said, I am doing it for you, so you don't have to.

    Args:
      segmentation_mask (array):
        original segmentation mask

    Returns:
      preprocessed segmentation_mask
    """
    return tf.abs(tf.cast(segmentation_mask, tf.float32) - 2)

def return_image_label_mask(ds_out):
    """ function to return image, class label and segmentation mask

    The original dataset contains additional information, such as the filename and
    the species. We don't care about any of that for this work, so will
    discard them and just keep the original image as our input, and then
    a tuple of our outputs that will be the class label and the semantic
    segmentation mask.

    Whilst we are here, we will also preprocess the segmentation mask.

    Args:
      ds_out: dict
        original dataset output

    Returns:
       RGB image
       tuple of class label and preprocessed segmentation mask
    """
    # preprocess the segmentation mask
    seg_mask =  preprocess_segmentation_mask(ds_out['segmentation_mask'])
    image = tf.cast(ds_out['image'], tf.float32)
    # image = standardise_image(image)
    return image, (ds_out['label'], seg_mask)

def mobilenet_preprocess_image(image):
    """Apply preprocessing that is suitable for MobileNetV3.
    
    Simply scales to ranges [-1, 1]
    
    
    you should use this preprocessing for both your model and the mobilenet model
    """
    image = (image - 127.5) / 255.0
    return image
    
    
def unprocess_image(image):
    """ undo preprocessing above so can plot images"""
    image = image * 255.0 + 127.5
    return image


def preprocess_and_resize(image, output, image_size):
    """apply preprocessing steps above to images and resize images and maps
    
    Each image in the dataset is of a different size. The resizing will make sure
    each image is the same size.
    """
    # resize the image and the semantic segmentation mask
    image = tf.image.resize(image, [image_size, image_size])
    image = mobilenet_preprocess_image(image)
    mask = tf.image.resize(output[1], [image_size, image_size])
    return image, (output[0], mask)

# %% [markdown]
# We will now put this all together into a helper function. You can use this directly as is and should be fine to hit the ground running. However, you may modify it to add some additional functionality such as data augmentation if you like.

# %%
# putting it all together into one big helper function

def load_oxford_pets(split,
                     batch_size=233,
                     shuffle=True,
                     image_size=300):
    """Load Oxford pets dataset for Assignment 1B

    Function handles loading of data for 1b, included processing of images and
    semantic segmentation masks. This function will
    organise the tensorflow dataset to return an output that is a tuple, where
    the tuple will be (classification_labels, segmentation_masks).

    Parameters
    ----------
    split : string
        either train or test string
    classification : bool
        whether to include classification labels
    segmentation : bool
        whether to include semantic segmentation masks
    batch_size : int
        size of batches to use
    shuffle : bool
        whether to shuffle the dataset (WILL ONLY APPLY TO TRAIN)
    image_size : int
        new image size

    Returns
    -------
       tf.Dataset containing the Oxford pets dataset
    """
    # lets do some error checking first
    if (split != 'train') and (split != 'test'):
        raise ValueError('Arg for split must be either \'train\' or \'test\'')
    if (split == 'test') and shuffle:
        print("WARNING: shuffle is set to true, but have specified split to be \'test\'")
        print('The shuffle argument will be ignored')
        shuffle = False
   
    # now start loading the dataset
    ds = tfds.load('oxford_iiit_pet',
                   split=split,
                   with_info=False)
    # remove unnecessary dataset info
    ds = ds.map(return_image_label_mask)

    # HINT: looks like a comfy spot for where some data augmentation might want to live ;)
    
    
    # Final processing of the data 
    # here we will resize the data, and add the preprocessing that is needed 
    # and compatable with the mobilenet models.
    ds = ds.map(lambda inp, out: preprocess_and_resize(inp, out, image_size))

    if split == 'train' and shuffle:
        ds = ds.shuffle(1000)
    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Testing the provided data loader.
#
# Let's test it all and plot some examples to make sure they are working. I have provided some bad defaults for the image size and the batch size.
#
# **YOU WILL NEED TO CHANGE THESE**, unless you have access to multiple A100 GPUS for some reason.

# %%
# testing it and plotting some images.
# NOTE: the image size I am setting here is all but definitely too large. You will need
# to chage this yourself to something that is suitable given your constraints
# NOTE: The batch size is also too large. I am doing this on purpose to force you to 
# pick a suitable batch size yourself
image_size = 128  # Decrease the image size to reduce memory usage
batch_size = 64  # Decrease the batch size to fit within the available GPU memory

train_class_seg_off = load_oxford_pets('train', shuffle=False, batch_size=batch_size, image_size=image_size)

train_class_seg = load_oxford_pets('train', shuffle=True, batch_size=batch_size, image_size=image_size)
test_class_seg = load_oxford_pets('test', shuffle=False, batch_size=batch_size, image_size=image_size)

# lets plot a few now to see some good kittens/doggos
fig, axs = plt.subplots(2, 3, figsize=(12, 6), layout="constrained")
num_plot = 3
i = 0
# each sample of our dataset will be of the format
# image, outputs
# where outputs[0] = label
#       outputs[1] = segmentation mask
#
#
# lets get a single batch, and plot just a few of them
for image, output in train_class_seg_off.take(1).as_numpy_iterator(): 
    for i in range(num_plot): 
        im = axs[0, i].imshow(np.squeeze(unprocess_image(image[i, ...])) / 255.0)
        im = axs[1, i].imshow(np.squeeze(output[1][i, ...]))
        print(output[1].shape)
        i += 1
        if i >= num_plot:
            break
        
plt.savefig('doggos_cattos.png')
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /opt/conda/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# (64, 128, 128, 1)
# (64, 128, 128, 1)
# (64, 128, 128, 1)

# %% [markdown]
# ### Pre-processing

# %%
# train_class_seg_off = train_class_seg_off.map(lambda x, y: preprocess_and_resize(x, y, image_size))
# train_class_seg = train_class_seg.map(lambda x, y: preprocess_and_resize(x, y, image_size))
# test_class_seg = test_class_seg.map(lambda x, y: preprocess_and_resize(x, y, image_size))

# %%
# !pip install tensorflow_addons

# %%
# import tensorflow_addons as tfa

# def random_rotations(image_batch, label_batch):
#     """Apply random rotations to the image batch"""
#     max_rotation = 0.785398  # 45 degrees in radians
#     rot_val = tf.random.uniform((), minval=-max_rotation, maxval=max_rotation, dtype=tf.float32)
#     rotated_images = tfa.image.rotate(image_batch, rot_val, fill_mode='nearest')
#     return rotated_images, label_batch

# # Apply random rotations to the dataset
# ds = train_class_seg_off.map(random_rotations)

# # Get the first batch from the dataset (original images and labels)
# x_original, y_original = next(iter(train_class_seg_off))

# # Get the first batch from the rotated dataset
# x_rotated, y_rotated = next(iter(ds))

# # Visualize the original and rotated images
# fig, axs = plt.subplots(1, 2)
# axs[0].imshow(tf.keras.preprocessing.image.array_to_img(x_original[0]))
# axs[0].set_title('Figure 1: Original Image')
# axs[1].imshow(tf.keras.preprocessing.image.array_to_img(x_rotated[0]))
# axs[1].set_title('Figure 2: Rotated Image')
# plt.show()

# %%
# train_class_seg = train_class_seg.map(random_rotations)

# %% [markdown]
# ### SELF

# %%
from tensorflow import keras
from tensorflow.keras import layers

# Backbone
input_img = Input(shape=(128, 128, 3))
x = Conv2D(8, (3, 3), activation='swish', padding='same')(input_img)
x = Conv2D(8, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(8, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(8, (3, 3), activation=None, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('swish')(x)
x = SpatialDropout2D(0.2)(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(16, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(16, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(16, (3, 3), activation=None, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('swish')(x)
x = SpatialDropout2D(0.2)(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(32, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(32, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(32, (3, 3), activation=None, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('swish')(x)
x = SpatialDropout2D(0.2)(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(64, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(64, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(64, (3, 3), activation= None, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('swish')(x)
x = SpatialDropout2D(0.2)(x)
encoded = MaxPooling2D((2, 2), padding='same', name='bottleneck')(x)

    # first output, we'll flatten the embedding, and pass it through a couple of dense layers to
    # get our output
class_out = Flatten()(encoded)
class_out = Dense(37, activation='softmax', name='class_output')(class_out)

    # second output, we'll do the usual decode to get our autoencoder output
x = Conv2D(64, (3, 3), activation='swish', padding='same')(encoded)
x = Conv2D(64, (3, 3), activation='swish', padding='same')(encoded)
x = Conv2D(64, (3, 3), activation='swish', padding='same')(encoded)
x = Conv2D(64, (3, 3), activation='swish', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(32, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(32, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(32, (3, 3), activation='swish', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(16, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(16, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(16, (3, 3), activation='swish', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(8, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(8, (3, 3), activation='swish', padding='same')(x)
x = Conv2D(8, (3, 3), activation='swish', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same', name='autoenc_output')(x)

# Build the model
model_cnn = Model(inputs=input_img, outputs=[class_out, decoded], name='multi_task_model')
# Print the summary
model_cnn.summary()
# Out:
# Model: "multi_task_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 8)  224         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 8)  584         ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 8)  584         ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 8)  584         ['conv2d_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128, 128, 8)  32         ['conv2d_3[0][0]']
#  alization)
#
#  activation (Activation)        (None, 128, 128, 8)  0           ['batch_normalization[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 128, 128, 8)  0          ['activation[0][0]']
#  out2D)
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 8)    0           ['spatial_dropout2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 16)   1168        ['max_pooling2d[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 16)   2320        ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 16)   2320        ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 16)   2320        ['conv2d_6[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_1[0][0]']
#
#  spatial_dropout2d_1 (SpatialDr  (None, 64, 64, 16)  0           ['activation_1[0][0]']
#  opout2D)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 16)  0           ['spatial_dropout2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 32)   4640        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 32)   9248        ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 32)   9248        ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 32)   9248        ['conv2d_10[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_2[0][0]']
#
#  spatial_dropout2d_2 (SpatialDr  (None, 32, 32, 32)  0           ['activation_2[0][0]']
#  opout2D)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)  0           ['spatial_dropout2d_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 64)   18496       ['max_pooling2d_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 64)   36928       ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 64)   36928       ['conv2d_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 64)   36928       ['conv2d_14[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_15[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_3[0][0]']
#
#  spatial_dropout2d_3 (SpatialDr  (None, 16, 16, 64)  0           ['activation_3[0][0]']
#  opout2D)
#
#  bottleneck (MaxPooling2D)      (None, 8, 8, 64)     0           ['spatial_dropout2d_3[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 8, 64)     36928       ['bottleneck[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 32)   18464       ['up_sampling2d[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 32)   9248        ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 32)   9248        ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 32)   9248        ['conv2d_22[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 32)  0           ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 16)   4624        ['up_sampling2d_1[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 16)   2320        ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 16)   2320        ['conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   2320        ['conv2d_26[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 16)  0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 8)    1160        ['up_sampling2d_2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 8)    584         ['conv2d_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 8)    584         ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 8)    584         ['conv2d_30[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['bottleneck[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 8)  0          ['conv2d_31[0][0]']
#
#  class_output (Dense)           (None, 37)           151589      ['flatten[0][0]']
#
#  autoenc_output (Conv2D)        (None, 128, 128, 1)  73          ['up_sampling2d_3[0][0]']
#
# ==================================================================================================
# Total params: 421,542
# Trainable params: 421,302
# Non-trainable params: 240
# __________________________________________________________________________________________________

# %%
model_cnn.compile(loss=['sparse_categorical_crossentropy', 'binary_crossentropy'],
              optimizer=keras.optimizers.Adam(), metrics=[[tf.keras.metrics.SparseCategoricalAccuracy()],[tf.keras.metrics.BinaryAccuracy()]])

history = model_cnn.fit(train_class_seg, epochs=20,#30
                         validation_data=test_class_seg, verbose= True )
# 200 terrible 
# 100 with text augmentation looks bad
# 100 looks overfitting
# Out:
# Epoch 1/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 24s 150ms/step - loss: 4.5592 - class_output_loss: 3.9204 - autoenc_output_loss: 0.6388 - class_output_sparse_categorical_accuracy: 0.0535 - autoenc_output_binary_accuracy: 0.6445 - val_loss: 4.4658 - val_class_output_loss: 3.6347 - val_autoenc_output_loss: 0.8311 - val_class_output_sparse_categorical_accuracy: 0.0273 - val_autoenc_output_binary_accuracy: 0.5731
# Epoch 2/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 128ms/step - loss: 4.1165 - class_output_loss: 3.5677 - autoenc_output_loss: 0.5488 - class_output_sparse_categorical_accuracy: 0.0731 - autoenc_output_binary_accuracy: 0.7277 - val_loss: 4.2802 - val_class_output_loss: 3.7032 - val_autoenc_output_loss: 0.5771 - val_class_output_sparse_categorical_accuracy: 0.0273 - val_autoenc_output_binary_accuracy: 0.7188
# Epoch 3/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 127ms/step - loss: 3.8999 - class_output_loss: 3.3636 - autoenc_output_loss: 0.5363 - class_output_sparse_categorical_accuracy: 0.0916 - autoenc_output_binary_accuracy: 0.7358 - val_loss: 4.2563 - val_class_output_loss: 3.6918 - val_autoenc_output_loss: 0.5645 - val_class_output_sparse_categorical_accuracy: 0.0275 - val_autoenc_output_binary_accuracy: 0.7224
# Epoch 4/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 124ms/step - loss: 3.8132 - class_output_loss: 3.2885 - autoenc_output_loss: 0.5247 - class_output_sparse_categorical_accuracy: 0.1101 - autoenc_output_binary_accuracy: 0.7429 - val_loss: 4.6088 - val_class_output_loss: 3.9110 - val_autoenc_output_loss: 0.6977 - val_class_output_sparse_categorical_accuracy: 0.0278 - val_autoenc_output_binary_accuracy: 0.6149
# Epoch 5/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 125ms/step - loss: 3.7000 - class_output_loss: 3.1882 - autoenc_output_loss: 0.5118 - class_output_sparse_categorical_accuracy: 0.1231 - autoenc_output_binary_accuracy: 0.7520 - val_loss: 4.5122 - val_class_output_loss: 3.9822 - val_autoenc_output_loss: 0.5300 - val_class_output_sparse_categorical_accuracy: 0.0289 - val_autoenc_output_binary_accuracy: 0.7354
# Epoch 6/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 123ms/step - loss: 3.5915 - class_output_loss: 3.0880 - autoenc_output_loss: 0.5035 - class_output_sparse_categorical_accuracy: 0.1473 - autoenc_output_binary_accuracy: 0.7558 - val_loss: 4.4075 - val_class_output_loss: 3.8664 - val_autoenc_output_loss: 0.5412 - val_class_output_sparse_categorical_accuracy: 0.0376 - val_autoenc_output_binary_accuracy: 0.7320
# Epoch 7/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 123ms/step - loss: 3.4815 - class_output_loss: 2.9838 - autoenc_output_loss: 0.4977 - class_output_sparse_categorical_accuracy: 0.1810 - autoenc_output_binary_accuracy: 0.7605 - val_loss: 4.1977 - val_class_output_loss: 3.6813 - val_autoenc_output_loss: 0.5164 - val_class_output_sparse_categorical_accuracy: 0.0583 - val_autoenc_output_binary_accuracy: 0.7457
# Epoch 8/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 124ms/step - loss: 3.3522 - class_output_loss: 2.8685 - autoenc_output_loss: 0.4837 - class_output_sparse_categorical_accuracy: 0.2136 - autoenc_output_binary_accuracy: 0.7678 - val_loss: 4.0036 - val_class_output_loss: 3.4964 - val_autoenc_output_loss: 0.5073 - val_class_output_sparse_categorical_accuracy: 0.0771 - val_autoenc_output_binary_accuracy: 0.7521
# Epoch 9/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 122ms/step - loss: 3.2115 - class_output_loss: 2.7373 - autoenc_output_loss: 0.4742 - class_output_sparse_categorical_accuracy: 0.2418 - autoenc_output_binary_accuracy: 0.7746 - val_loss: 4.3826 - val_class_output_loss: 3.8982 - val_autoenc_output_loss: 0.4844 - val_class_output_sparse_categorical_accuracy: 0.0668 - val_autoenc_output_binary_accuracy: 0.7685
# Epoch 10/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 124ms/step - loss: 3.0295 - class_output_loss: 2.5696 - autoenc_output_loss: 0.4599 - class_output_sparse_categorical_accuracy: 0.2812 - autoenc_output_binary_accuracy: 0.7830 - val_loss: 3.7696 - val_class_output_loss: 3.3236 - val_autoenc_output_loss: 0.4459 - val_class_output_sparse_categorical_accuracy: 0.1330 - val_autoenc_output_binary_accuracy: 0.7928
# Epoch 11/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 123ms/step - loss: 2.7931 - class_output_loss: 2.3446 - autoenc_output_loss: 0.4485 - class_output_sparse_categorical_accuracy: 0.3389 - autoenc_output_binary_accuracy: 0.7898 - val_loss: 3.9041 - val_class_output_loss: 3.4642 - val_autoenc_output_loss: 0.4399 - val_class_output_sparse_categorical_accuracy: 0.1120 - val_autoenc_output_binary_accuracy: 0.7953
# Epoch 12/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 125ms/step - loss: 2.5932 - class_output_loss: 2.1481 - autoenc_output_loss: 0.4451 - class_output_sparse_categorical_accuracy: 0.3935 - autoenc_output_binary_accuracy: 0.7926 - val_loss: 4.1470 - val_class_output_loss: 3.7092 - val_autoenc_output_loss: 0.4378 - val_class_output_sparse_categorical_accuracy: 0.1300 - val_autoenc_output_binary_accuracy: 0.7974
# Epoch 13/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 124ms/step - loss: 2.3445 - class_output_loss: 1.9116 - autoenc_output_loss: 0.4329 - class_output_sparse_categorical_accuracy: 0.4489 - autoenc_output_binary_accuracy: 0.7977 - val_loss: 3.9618 - val_class_output_loss: 3.5432 - val_autoenc_output_loss: 0.4186 - val_class_output_sparse_categorical_accuracy: 0.1401 - val_autoenc_output_binary_accuracy: 0.8059
# Epoch 14/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 123ms/step - loss: 2.0221 - class_output_loss: 1.6016 - autoenc_output_loss: 0.4204 - class_output_sparse_categorical_accuracy: 0.5307 - autoenc_output_binary_accuracy: 0.8039 - val_loss: 4.1867 - val_class_output_loss: 3.7705 - val_autoenc_output_loss: 0.4162 - val_class_output_sparse_categorical_accuracy: 0.1404 - val_autoenc_output_binary_accuracy: 0.8100
# Epoch 15/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 124ms/step - loss: 1.7267 - class_output_loss: 1.3155 - autoenc_output_loss: 0.4112 - class_output_sparse_categorical_accuracy: 0.6125 - autoenc_output_binary_accuracy: 0.8089 - val_loss: 4.2310 - val_class_output_loss: 3.8204 - val_autoenc_output_loss: 0.4106 - val_class_output_sparse_categorical_accuracy: 0.1453 - val_autoenc_output_binary_accuracy: 0.8113
# Epoch 16/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 124ms/step - loss: 1.4045 - class_output_loss: 1.0003 - autoenc_output_loss: 0.4041 - class_output_sparse_categorical_accuracy: 0.7038 - autoenc_output_binary_accuracy: 0.8129 - val_loss: 4.6482 - val_class_output_loss: 4.2311 - val_autoenc_output_loss: 0.4171 - val_class_output_sparse_categorical_accuracy: 0.1412 - val_autoenc_output_binary_accuracy: 0.8067
# Epoch 17/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 123ms/step - loss: 1.1769 - class_output_loss: 0.7784 - autoenc_output_loss: 0.3986 - class_output_sparse_categorical_accuracy: 0.7677 - autoenc_output_binary_accuracy: 0.8148 - val_loss: 4.6286 - val_class_output_loss: 4.2251 - val_autoenc_output_loss: 0.4036 - val_class_output_sparse_categorical_accuracy: 0.1357 - val_autoenc_output_binary_accuracy: 0.8147
# Epoch 18/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 124ms/step - loss: 0.9548 - class_output_loss: 0.5635 - autoenc_output_loss: 0.3913 - class_output_sparse_categorical_accuracy: 0.8402 - autoenc_output_binary_accuracy: 0.8183 - val_loss: 4.7412 - val_class_output_loss: 4.3468 - val_autoenc_output_loss: 0.3944 - val_class_output_sparse_categorical_accuracy: 0.1475 - val_autoenc_output_binary_accuracy: 0.8187
# Epoch 19/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 123ms/step - loss: 0.8121 - class_output_loss: 0.4276 - autoenc_output_loss: 0.3845 - class_output_sparse_categorical_accuracy: 0.8764 - autoenc_output_binary_accuracy: 0.8228 - val_loss: 4.9871 - val_class_output_loss: 4.5921 - val_autoenc_output_loss: 0.3950 - val_class_output_sparse_categorical_accuracy: 0.1434 - val_autoenc_output_binary_accuracy: 0.8209
# Epoch 20/20
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 8s 124ms/step - loss: 0.6889 - class_output_loss: 0.3112 - autoenc_output_loss: 0.3777 - class_output_sparse_categorical_accuracy: 0.9139 - autoenc_output_binary_accuracy: 0.8261 - val_loss: 5.1592 - val_class_output_loss: 4.7698 - val_autoenc_output_loss: 0.3894 - val_class_output_sparse_categorical_accuracy: 0.1466 - val_autoenc_output_binary_accuracy: 0.8212

# %%
fig = plt.figure(figsize=[20, 6])
ax = fig.add_subplot(1, 2, 1)

ax.plot(history.history['class_output_sparse_categorical_accuracy'], label="Training class Accuracy ")
ax.plot(history.history['val_class_output_sparse_categorical_accuracy'], label="Test class Accuracy ")

ax.legend()

ax = fig.add_subplot(1, 2, 2)

ax.plot(history.history['autoenc_output_binary_accuracy'], label="Training mask Accuracy")
ax.plot(history.history['val_autoenc_output_binary_accuracy'], label="Test mask Accuracy")
ax.legend()

# %%
x, y = next(iter(test_class_seg))
classification, decoded = model_cnn(x)
fig, axs = plt.subplots(1, 2)
axs[0].imshow(tf.keras.preprocessing.image.array_to_img(x[0]))
axs[1].imshow(tf.keras.preprocessing.image.array_to_img(decoded[0]))

# %%
# def eval_model_1(pred_train, train, train_y, ):


#     indexes = tf.argmax(pred_train, axis=1)


#     fig = plt.figure(figsize=[10, 10])
#     cm = confusion_matrix(train_y, indexes)

#     ax = fig.add_subplot(1, 1, 1)
#     ax.set_title('Training, F1 Score: %f' % f1_score(train_y, indexes, average='weighted'))
#     c = ConfusionMatrixDisplay(cm)
#     c.plot(ax = ax)

#     # repeat visualisation for the test set
# def eval_model_2(pred_test,test, test_y):


#     indexes = tf.argmax(pred_test, axis=1)


#     fig = plt.figure(figsize=[10, 10])


#     indexes = tf.argmax(pred_test, axis=1)
#     cm = confusion_matrix(test_y, indexes)
#     ax = fig.add_subplot(1, 1, 1)
#     ax.set_title('Testing, F1 Score: %f' % f1_score(test_y, indexes, average='weighted'))
#     c = ConfusionMatrixDisplay(cm)
#     c.plot(ax = ax)

# %%
def eval_model(pred_train, train, train_y, pred_test, test, test_y):
    train_indexes = tf.argmax(pred_train, axis=1)
    test_indexes = tf.argmax(pred_test, axis=1)

    train_cm = confusion_matrix(train_y, train_indexes)
    test_cm = confusion_matrix(test_y, test_indexes)

    fig, axes = plt.subplots(1, 2, figsize=[20, 10])

    ax1 = axes[0]
    ax1.set_title('Training, F1 Score: %f' % f1_score(train_y, train_indexes, average='weighted'))
    train_cm_display = ConfusionMatrixDisplay(train_cm)
    train_cm_display.plot(ax=ax1)

    ax2 = axes[1]
    ax2.set_title('Testing, F1 Score: %f' % f1_score(test_y, test_indexes, average='weighted'))
    test_cm_display = ConfusionMatrixDisplay(test_cm)
    test_cm_display.plot(ax=ax2)

    plt.show()

# %%
# def eval_model(pred_train, train, train_y,pred_test,test, test_y ):


#     indexes = tf.argmax(pred_train, axis=1)


#     fig = plt.figure(figsize=[10, 10])
#     cm = confusion_matrix(train_y, indexes)

#     ax = fig.add_subplot(1, 2, 1)
#     ax.set_title('Training, F1 Score: %f' % f1_score(train_y, indexes, average='weighted'))
#     c = ConfusionMatrixDisplay(cm)
#     c.plot(ax = ax)
    
#     indexes = tf.argmax(pred_test, axis=1)


#     fig = plt.figure(figsize=[10, 10])


#     indexes = tf.argmax(pred_test, axis=1)
#     cm = confusion_matrix(test_y, indexes)
#     ax = fig.add_subplot(1, 2, 2)
#     ax.set_title('Testing, F1 Score: %f' % f1_score(test_y, indexes, average='weighted'))
#     c = ConfusionMatrixDisplay(cm)
#     c.plot(ax = ax)

# %%
class_train, seg_train = model_cnn.predict(train_class_seg_off)
class_results, mask_results= model_cnn.predict(test_class_seg)
# predicted_labels = np.argmax(class_results, axis =1)
 
y_train_class =np.concatenate([y[0] for x,y in train_class_seg_off.as_numpy_iterator()])
y_train_seg = np.concatenate([y[1] for x,y in train_class_seg_off.as_numpy_iterator()])
y_test_class =np.concatenate([y[0] for x,y in test_class_seg.as_numpy_iterator()])
y_test_seg = np.concatenate([y[1] for x,y in test_class_seg.as_numpy_iterator()])

# eval_model_1(class_train, train_class_seg_off, y_train_class)
# eval_model_1(class_results, test_class_seg, y_test_class)
eval_model(class_train, train_class_seg_off, y_train_class, class_results, test_class_seg, y_test_class)
# Out:
# 13/58 [=====>........................] - ETA: 2s
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 3s 42ms/step
# 58/58 [==============================] - 2s 40ms/step
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment

# %%
# class_preds, seg_preds = model_cnn.predict(test_class_seg)
# seg_preds_flat = seg_preds.reshape(-1) > 0.5 # flatten predictions, turn into boolean vector where true is fgnd and false is bkgnd
# seg_gt_flat = some_pred_y_data.reshape(-1) > 0.5 # same as above, but for the ground truth, need to have both as a boolean vector

##### Simon email 
class_preds, seg_preds = model_cnn.predict(test_class_seg)
seg_preds_flat = seg_preds.reshape(-1) > 0.5 # flatten predictions, turn into boolean vector where true is fgnd and false is bkgnd
seg_gt_flat = y_test_seg.reshape(-1) > 0.5 # same as above, but for the ground truth, need to have both as a boolean vector


cm = sklearn.metrics.confusion_matrix(seg_gt_flat, seg_preds_flat, normalize='true')

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the confusion matrix using a heatmap
sns.heatmap(cm, annot=True, fmt="%", cmap="Blues", cbar=False, ax=ax)

# Set labels, title, and ticks
ax.set_xlabel('Predicted')
ax.set_ylabel('True')
ax.set_title('Confusion Matrix using the From Scratch approach')
ax.xaxis.set_ticklabels(['Background', 'Foreground'])
ax.yaxis.set_ticklabels(['Background', 'Foreground'])

# Display the plot
plt.show()
# Out:
# 58/58 [==============================] - 2s 41ms/step

# %%
# cm = cm = sklearn.metrics.confusion_matrix(true_labels, predicted_labels)
# fig = plt.figure(figsize= [10,10])
# ax = fig.add_subplot(1,1,1)
# c = ConfusionMatrixDisplay(cm)
# c.plot(ax=ax)

# %%
# def evaluate_decoded_images(decoded_imgs, test_images, pred, pred_y,):
#     # Calculate evaluation metrics for decoded images
#     rmse = np.sqrt(np.mean((test_images - decoded_imgs) ** 2))
#     values= tf.argmax(pred, axis=1)
#     #ori_values =tf.argmax(pred_y, axis=1)
#     print("Mean Squared Error (MSE):", rmse)
#     fig = plt.figure(figsize=[25, 10])


#     fig = plt.figure(figsize=[25, 15])
#     count = 0

#     for i in range(1):
#         for j in range(4):
#             ax = fig.add_subplot(2, 6, count + 1)
#             ax.imshow(np.squeeze(test_images[j]))
#             ax.set_title('True Class Label: {}'.format(pred_y[j]))
#             count+= 1
#             ax = fig.add_subplot(2, 6, count+ 1)
#             ax.imshow(np.squeeze(decoded_imgs[j]))
#             ax.set_title('Predicted Class Label: {}'.format(values[j]));
#             count+= 1
#     plt.show()

# %%
# # Extract seg labels
# cm = sklearn.metrics.confusion_matrix(seg_gt_flat, seg_preds_flat)
# fig = plt.figure(figsize=[10,10])
# ax = fig.add_subplot(1,1,1)
# c = ConfusionMatrixDisplay(cm)
# c.plot(ax=ax)

# %% [markdown]
# # Loading MobileNetV3Small base for fine tuning
#
# This model can be loaded directly from Tensorflow. By default, the model we download will be pre-trained on Imagenet dataset.
#
# Note that we will need to set the preprocessing option when loading this base network to False.
#     This is because the `include_preprocessing` step is implemented in the Datasets we defined above.
#
# We also set `include_top=False`, to avoid loading our model with the final Dense classification layer which is used for the original Imagenet model.

# %%
mobile_base = tf.keras.applications.MobileNetV3Small(input_shape=(image_size, image_size, 3),
                                                  include_top=False,
                                                  include_preprocessing=False)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
# mobile_base.summary()

# %%
mobile_base.trainable = False
# mobile_base.summary()

# %%
from tensorflow.keras import layers
# setting up base network / encoder to get embedding
inputs = layers.Input((image_size, image_size, 3))
embedding = mobile_base(inputs)

# classification output
flattened = layers.GlobalAveragePooling2D(name='gap')(embedding)
classification = layers.Dense(37, activation=None, name='classification')(flattened)

# decoder
x =  layers.UpSampling2D((3, 3))(embedding)
x =  layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x =  layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)

x =  layers.UpSampling2D((3, 3))(x)
x =  layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x =  layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)

x =  layers.UpSampling2D((3, 3))(x)
x =  layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x =  layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)


# output - for binary semantic segmentation - one channel
x =  layers.Conv2D(1, (1, 1), activation=None, padding='same')(x)
decoded = keras.layers.Resizing(image_size, image_size)(x)

mobile_model = keras.Model(inputs, [classification, decoded])
mobile_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  MobilenetV3small (Functional)  (None, 4, 4, 576)    939120      ['input_3[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 12, 12, 576)  0          ['MobilenetV3small[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 12, 12, 64)   331840      ['up_sampling2d_4[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 12, 64)   36928       ['conv2d_32[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 36, 36, 64)  0           ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 36, 36, 32)   18464       ['up_sampling2d_5[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 36, 36, 32)   9248        ['conv2d_34[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 108, 108, 32  0          ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 108, 108, 16  4624        ['up_sampling2d_6[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 108, 108, 16  2320        ['conv2d_36[0][0]']
#                                 )
#
#  gap (GlobalAveragePooling2D)   (None, 576)          0           ['MobilenetV3small[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 108, 108, 1)  17          ['conv2d_37[0][0]']
#
#  classification (Dense)         (None, 37)           21349       ['gap[0][0]']
#
#  resizing (Resizing)            (None, 128, 128, 1)  0           ['conv2d_38[0][0]']
#
# ==================================================================================================
# Total params: 1,363,910
# Trainable params: 424,790
# Non-trainable params: 939,120
# __________________________________________________________________________________________________

# %%
mobile_model.compile(loss=[keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                           keras.losses.MeanSquaredError()],
                  optimizer='adam')

# %%
history = mobile_model.fit(train_class_seg, epochs=10,
                     validation_data=test_class_seg)
# Out:
# Epoch 1/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 12s 109ms/step - loss: 3.1958 - classification_loss: 2.9642 - resizing_loss: 0.2315 - val_loss: 2.3326 - val_classification_loss: 2.1944 - val_resizing_loss: 0.1382
# Epoch 2/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 6s 84ms/step - loss: 1.8414 - classification_loss: 1.7243 - resizing_loss: 0.1171 - val_loss: 1.7664 - val_classification_loss: 1.6562 - val_resizing_loss: 0.1103
# Epoch 3/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 6s 83ms/step - loss: 1.4142 - classification_loss: 1.3088 - resizing_loss: 0.1054 - val_loss: 1.5717 - val_classification_loss: 1.4648 - val_resizing_loss: 0.1069
# Epoch 4/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 5s 83ms/step - loss: 1.2006 - classification_loss: 1.1002 - resizing_loss: 0.1004 - val_loss: 1.4701 - val_classification_loss: 1.3698 - val_resizing_loss: 0.1003
# Epoch 5/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 5s 82ms/step - loss: 1.0666 - classification_loss: 0.9681 - resizing_loss: 0.0985 - val_loss: 1.4135 - val_classification_loss: 1.3140 - val_resizing_loss: 0.0995
# Epoch 6/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 6s 85ms/step - loss: 0.9602 - classification_loss: 0.8669 - resizing_loss: 0.0932 - val_loss: 1.3785 - val_classification_loss: 1.2849 - val_resizing_loss: 0.0936
# Epoch 7/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 5s 81ms/step - loss: 0.8827 - classification_loss: 0.7925 - resizing_loss: 0.0902 - val_loss: 1.3443 - val_classification_loss: 1.2525 - val_resizing_loss: 0.0918
# Epoch 8/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 5s 83ms/step - loss: 0.8184 - classification_loss: 0.7302 - resizing_loss: 0.0882 - val_loss: 1.3261 - val_classification_loss: 1.2333 - val_resizing_loss: 0.0928
# Epoch 9/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 5s 82ms/step - loss: 0.7599 - classification_loss: 0.6730 - resizing_loss: 0.0869 - val_loss: 1.3202 - val_classification_loss: 1.2303 - val_resizing_loss: 0.0898
# Epoch 10/10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 6s 83ms/step - loss: 0.7087 - classification_loss: 0.6257 - resizing_loss: 0.0830 - val_loss: 1.3088 - val_classification_loss: 1.2179 - val_resizing_loss: 0.0909

# %%
class_train, seg_train = mobile_model.predict(train_class_seg_off)
class_results, mask_results= mobile_model.predict(test_class_seg)
# predicted_labels = np.argmax(class_results, axis =1)

# eval_model_1(class_train, train_class_seg_off, y_train_class)
# eval_model_1(class_results, test_class_seg, y_test_class)
eval_model(class_train, train_class_seg_off, y_train_class, class_results, test_class_seg, y_test_class)
# Out:
# 13/58 [=====>........................] - ETA: 2s
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 58/58 [==============================] - 3s 40ms/step
# 58/58 [==============================] - 2s 39ms/step

# %%
# x, y = next(iter(test_class_seg))
# classification, decoded = mobile_model(x)
# fig, axs = plt.subplots(1, 2)
# axs[0].imshow(tf.keras.preprocessing.image.array_to_img(x[0]))
# axs[1].imshow(tf.keras.preprocessing.image.array_to_img(decoded[0]))

# %%
# class_preds, seg_preds = model_cnn.predict(test_class_seg)
# seg_preds_flat = seg_preds.reshape(-1) > 0.5 # flatten predictions, turn into boolean vector where true is fgnd and false is bkgnd
# seg_gt_flat = some_pred_y_data.reshape(-1) > 0.5 # same as above, but for the ground truth, need to have both as a boolean vector

##### Simon email 
class_preds, seg_preds = mobile_model.predict(test_class_seg)
seg_preds_flat = seg_preds.reshape(-1) > 0.5 # flatten predictions, turn into boolean vector where true is fgnd and false is bkgnd
seg_gt_flat = y_test_seg.reshape(-1) > 0.5 # same as above, but for the ground truth, need to have both as a boolean vector
# Out:
# 58/58 [==============================] - 2s 41ms/step

# %%
cm = sklearn.metrics.confusion_matrix(seg_gt_flat, seg_preds_flat, normalize='true')

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the confusion matrix using a heatmap
sns.heatmap(cm, annot=True, fmt="%", cmap="Blues", cbar=False, ax=ax)

# Set labels, title, and ticks
ax.set_xlabel('Predicted')
ax.set_ylabel('True')
ax.set_title('Confusion Matrix using the MobileNetV3Small approach')
ax.xaxis.set_ticklabels(['Background', 'Foreground'])
ax.yaxis.set_ticklabels(['Background', 'Foreground'])

# Display the plot
plt.show()
